# %% [markdown]
# <a href="https://colab.research.google.com/github/yahir067244/OAC_LAB/blob/lab_2/lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="......"/>
#
# # Lab 2: Construcción de máquinas de estados usando memorias
#
# ## Configuración <a id="setting-token"></a>
#
# Asegurate de configurar tu cuenta cómo lo hiciste en el Lab-0:
#
# 1. En la siguiente celda cambia `deleteThisAndPasteHostHere` por el host y `deleteThisAndPasteYourTokenHere` por tu token.

# %%
import os
from client import configure, health_check, grade, check_lab_completion_status

configure(
    server_url=os.environ.get("GRADE_SERVER_URL", "https://grades.jace.org.in"),
    token=os.environ.get("GRADE_TOKEN", "grade_VcCUWKxSo0c9R8l1AL1zMemfmjfLptFgSohKpSFAV3I"),
)

# %% [markdown]
# ## Comprobar el servidor <a id="sanity-check"></a>

# %%
health_check()
# Out:
# True

# %% [markdown]
# ## 1. Direccionamiento entrada-estado
#
# Otra forma de almacenar información en la ROM es restringiendo la carta ASM a una máquina de estados con una entrada por estado. Un nuevo bloque en la ROM especifica la entrada elegida por cada estado. Este bloque se denomina **Prueba**. La parte de Liga ahora contempla dos posibles estados siguientes, determinados por el resultado de la entrada seleccionada por el bloque de Prueba. En conclusión, cada dirección de esta ROM selecciona una palabra o registro que describe un par estado-entrada.

# %% [markdown]
# Para describir el direccionamiento entrada-estado se tiene la siguiente carta ASM:
#
# <img src="......"/>

# %% [markdown]
# 1. En el bloque de Prueba se debe almacenar la asignación binaria a los entradas, es decir, se debe asignar un código binario a cada entrada que aparece en la máquina de estados. Nosotros decidimos el orden y el valor que le corresponde a cada entrada y lo escribimos en una tabla:
#
# | Entrada | Prueba |
# | :-------: | :------: |
# | X       | 00    |
# | Y       | 01    |
# | Z       | 10    |
#
#
# 2. El tamaño de la memoria es:
# - $n = 2 = 2$
# - $m = 2 + 2 + 2 + 3 = 9$
# - $2^n * m = 2²*9$ bits
# 3. El contenido de la memoria es:
#
# <table style="border: 2px solid #333333; border-collapse: collapse">
#   <thead>
#     <tr style="background-color: #f2f2f2">
#       <th style="border: 1px solid #333333; padding: 12px; text-align: center">
#         Edo Presente <br />
#         P1 P0
#       </th>
#       <th style="border: 1px solid #333333; padding: 12px; text-align: center">
#         Prueba <br />
#         K1 K0
#       </th>
#       <th style="border: 1px solid #333333; padding: 12px; text-align: center">
#         Liga Falsa<br />
#         F1 F0
#       </th>
#       <th style="border: 1px solid #333333; padding: 12px; text-align: center">
#         Liga Verdadera<br />
#         V1 V0
#       </th>
#       <th style="border: 1px solid #333333; padding: 12px; text-align: center">
#         Salidas <br />
#         S2 S1 S0
#       </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         00
#       </td>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         00
#       </td>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         01
#       </td>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         11
#       </td>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         0 0 1
#       </td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         01
#       </td>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         10
#       </td>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         01
#       </td>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         11
#       </td>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         0 0 0
#       </td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         10
#       </td>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         **
#       </td>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         00
#       </td>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         00
#       </td>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         1 0 1
#       </td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         11
#       </td>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         01
#       </td>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         00
#       </td>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         10
#       </td>
#       <td style="border: 1px solid #333333; padding: 12px; text-align: center">
#         1 0 0
#       </td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Nota sobre el uso de don't care</b>
#
#
# Cuando el **don't care (*)** aparece en la parte del contenido de la memoria tiene un uso diferente, en estos casos solo se debe elegir una y solo una combinación. Por ejemplo, el estado 2 se puede representar de estas distintas maneras:
#
# | Estado | Prueba | LF | LV | Salidas |
# | :-----: | :-----: | :----: | :----: | :----: |
# | 10 | 00 | 00 | 00 | 101 |
# | 10 | 01 | 00 | 00 | 101 |
# | 10 | 10 | 00 | 00 | 101 |
# | 10 | 11 | 00 | 00 | 101 |
#
# Al grabar la memoria **solo elegimos una de estas opciones**, por practicidad siempre se elige la combinación donde $Prueba = 00$.
# </div>

# %% [markdown]
# Para almacenar el contenido de la memoria en el diccionario de datos toma en cuenta las siguientes consideraciones:
#
# 1. Usa don't care cuando sea necesario.
# 2. No llenes las direcciones de memoria que no se usan, es decir, llena solo las de los estados que si aparecen en la carta ASM.
#
# A continuación se muestra como quedaría el diccionario de datos:

# %%
# (edo presente) : (Prueba, Liga Falsa, Liga Verdadera, Salidas)

ee1 = {
    ("00"):("00", "01", "11", "001"),
    ("01"):("10", "01", "11", "000"),
    ("10"):("**", "00", "00", "101"),
    ("11"):("10", "00", "10", "100")
}

# Imprimir el contenido en la direccion dada por el estado presente:

estado = "00"

prueba, lf, lv, salida = ee1[estado]

print("Prueba:", prueba)
print("Liga Falsa:", lf)
print("Liga Verdadera:", lv)
print("Salidas:", salida)
# Out:
# Prueba: 00
# Liga Falsa: 01
# Liga Verdadera: 11
# Salidas: 001

# %% [markdown]
# ## 2. Modificando la carta ASM
#
# Se han aplicado los siguientes cambios a la carta ASM:
#
# <img src="......"/>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ejercicio 1: Obten el tamaño de la memoria usando el direccionamiento entrada-estado</b>
#
# **Tu objetivo:**  obtener el número de registros `2^n` y el tamaño de cada registro `m`. El resultado debes guardarlo en la lista **tm_entrada_estado**.
# </div>

# %%
#### ESCRIBE TU CODIGO AQUI ###

# llena la lista con valores enteros usando el siguiente orden:
# tm_trayectoria = [2^n, m]
tm_entrada_estado = [4, 9]


### TU CODIGO ACABA AQUI    ###

# %%
# Entrega tu respuesta usando el siguiente codigo
grade(tm_entrada_estado, "lab2-ex1", "OAC-2027-1")
# Out:
# Submitting your answer. Please wait...
# Congratulations! Your answer is correct. (score: 1.0)
# {'data': {'grading_validation': 'valid',
#   'grading_score': 1.0,
#   'grading_error': None}}

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ejercicio 2: Obten el contenido de la memoria usando el direccionamiento entrada-estado</b>
#
# **Tu objetivo:**  obtener la dirección y el contenido correspondiente a cada estado en la Carta ASM. El resultado se debe guardar en el dicconario de datos **c_entrada_estado**. Los valores de prueba que debes usar son los siguientes:
#
# | Entrada | prueba |
# | :-------: | :------: |
# | Y       | 00    |
# | Z       | 01    |
# | X       | 10    |
#
# **Pista:** Utiliza el direccionamiento entrada-estado modificado.
#
# </div>
# <div class="alert alert-block alert-warning">
#
# ⚠️ **Nota:** Recuerda usar don't care cuando sea necesario.
# </div>

# %%
### ESCRIBE TU CODIGO AQUI ###

# (edo presente) : (prueba, liga falsa, liga verdadera, salidas falsas, salidas verdaderas)
c_entrada_estado = {
    ("00"):("10", "01", "11", "011", "001" ),
    ("01"):("01", "01", "11", "001", "000"),
    ("10"):("**", "00", "00", "101", "101"),
    ("11"):("00", "00", "10", "100", "110")
}

### TU CODIGO ACABA AQUI    ###

# %%
# Entrega tu respuesta usando el siguiente codigo
grade(c_entrada_estado, "lab2-ex2", "OAC-2027-1")
# Out:
# Submitting your answer. Please wait...
# Congratulations! Your answer is correct. (score: 1.0)
# {'data': {'grading_validation': 'valid',
#   'grading_score': 1.0,
#   'grading_error': None}}

# %%
# Consulta tu progreso usando el siguiente codigo
check_lab_completion_status("OAC-2027-1")
# Out:
# lab0: 3/3 exercises completed (100%)
# lab1: 3/3 exercises completed (100%)
# lab2: 2/2 exercises completed (100%)
# {'lab0': {'completed': 3, 'total': 3},
#  'lab1': {'completed': 3, 'total': 3},
#  'lab2': {'completed': 2, 'total': 2}}

# %% [markdown]
# # Información adicional
#
# **Creado por:** Julio Cesar Cruz Estrada
#
# **Version:** 1.0.0
